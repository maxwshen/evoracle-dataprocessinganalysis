# %%
import numpy as np, seaborn as sns, matplotlib.pyplot as plt, pandas as pd

import sys
sys.path.append('/ahg/regevdata/projects/CRISPR-libraries/prj2/evolution/abe8e/src/')
import e2_fullgts_trajectory as parent_script
import _config

design_df = pd.read_csv(_config.DATA_DIR + 'exp_design.csv')
# Out:
# Using data folder:
#  /ahg/regevdata/projects/CRISPR-libraries/prj2/evolution/abe8e/data/

# %%
df = pd.read_csv(parent_script.out_dir + f'pv_fullgts_trajectory.csv', index_col = 0)
print(df.shape)
# Out:
# (13841, 100)

# %% [markdown]
# ## form truncated

# %%
df['Max'] = df.apply('max', axis = 'columns')

# %%
thresholds = [0.10, 0.05, 0.04, 0.03, 0.02, 0.01]

for threshold in thresholds:
    n = sum(df['Max'] > threshold)
    print(f'Above {threshold:.0%}: {n} genotypes')
# Out:
# Above 10%: 4 genotypes
# Above 5%: 12 genotypes
# Above 4%: 23 genotypes
# Above 3%: 33 genotypes
# Above 2%: 62 genotypes
# Above 1%: 130 genotypes

# %% [markdown]
# ## plot truncated

# %%
threshold = 0.05

df3 = df[df['Max'] > threshold]

df3 = df3.drop(['Max'], axis = 'columns')
df3 = df3.set_index('Full genotype')
# df3 = df3.div(df3.sum(axis = 'rows'), axis = 'columns')
# df3 = df3.reset_index()
dfm3 = df3

dfm3 = dfm3.melt(id_vars = 'Full genotype', var_name = 'Sample name', value_name = 'Frequency')
dfm3['Sample'] = [int(s.split()[-1]) for s in dfm3['Sample name']]

# Shuffle rows for random colors
dfm3 = dfm3.sample(frac = 1)

# %%
fig, ax = plt.subplots(figsize = (16, 5))
sns.lineplot(
    x = 'Sample',
    y = 'Frequency',
    hue = 'Full genotype',
    data = dfm3,
#     style = 'Full genotype',
    ax = ax,
)
sns.despine()
plt.grid(alpha = 0.2)
plt.legend(bbox_to_anchor = (1.05, 1), loc = 'upper left')

# %% [markdown]
# ## Plot subset of regimes

# %%
def get_campaign_a(dfm3):
    allowed_samples = list(range(1, 20 + 1)) + list(range(41, 50 + 1)) + list(range(86, 92 + 1))
    crit = (dfm3['Sample'].isin(allowed_samples))
    dfs = dfm3[crit]
    dfs['Sample'] = [str(s).zfill(2) for s in dfs['Sample']]
    return dfs

dfs = get_campaign_a(dfm3)

fig, ax = plt.subplots(figsize = (16, 5))
sns.lineplot(
    x = 'Sample',
    y = 'Frequency',
    hue = 'Full genotype',
    data = dfs,
    ax = ax,
)
sns.despine()
plt.grid(alpha = 0.2)
plt.title(f'LowPANCE1 -> HighPANCE1 -> PACE2');
plt.legend(bbox_to_anchor = (1.05, 1), loc = 'upper left')
# Out:
# /ahg/regevdata/users/maxwshen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
def get_campaign_b(dfm3):
    allowed_samples = list(range(1, 20 + 1)) + list(range(41, 50 + 1)) + list(range(93, 99 + 1))
    crit = (dfm3['Sample'].isin(allowed_samples))
    dfs = dfm3[crit]
    dfs['Sample'] = [str(s).zfill(2) for s in dfs['Sample']]
    return dfs

dfs = get_campaign_b(dfm3)

fig, ax = plt.subplots(figsize = (16, 5))
sns.lineplot(
    x = 'Sample',
    y = 'Frequency',
    hue = 'Full genotype',
    data = dfs,
    ax = ax,
)
sns.despine()
plt.grid(alpha = 0.2)
plt.title(f'LowPANCE1 -> HighPANCE1 -> PACE3');
plt.legend(bbox_to_anchor = (1.05, 1), loc = 'upper left')
# Out:
# /ahg/regevdata/users/maxwshen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
def get_campaign_c(dfm3):
    allowed_samples = list(range(21, 40 + 1)) + list(range(51, 60 + 1)) + list(range(93, 99 + 1))
    crit = (dfm3['Sample'].isin(allowed_samples))
    dfs = dfm3[crit]
    dfs['Sample'] = [str(s).zfill(2) for s in dfs['Sample']]
    return dfs

dfs = get_campaign_c(dfm3)

fig, ax = plt.subplots(figsize = (16, 5))
sns.lineplot(
    x = 'Sample',
    y = 'Frequency',
    hue = 'Full genotype',
    data = dfs,
    ax = ax,
)
sns.despine()
plt.grid(alpha = 0.2)
plt.title(f'LowPANCE2 -> HighPANCE2 -> PACE3');
plt.legend(bbox_to_anchor = (1.05, 1), loc = 'upper left')
# Out:
# /ahg/regevdata/users/maxwshen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
def get_campaign_c(dfm3):
    allowed_samples = list(range(21, 40 + 1)) + list(range(70, 78 + 1)) + list(range(79, 85 + 1))
    crit = (dfm3['Sample'].isin(allowed_samples))
    dfs = dfm3[crit]
    dfs['Sample'] = [str(s).zfill(2) for s in dfs['Sample']]
    return dfs

dfs = get_campaign_c(dfm3)

fig, ax = plt.subplots(figsize = (16, 5))
sns.lineplot(
    x = 'Sample',
    y = 'Frequency',
    hue = 'Full genotype',
    data = dfs,
    ax = ax,
)
sns.despine()
plt.grid(alpha = 0.2)
plt.title(f'LowPANCE2 -> HighPANCE4 -> PACE1');
plt.legend(bbox_to_anchor = (1.05, 1), loc = 'upper left')
# Out:
# /ahg/regevdata/users/maxwshen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
def get_campaign_c(dfm3):
    allowed_samples = list(range(1, 20 + 1)) + list(range(61, 69 + 1)) + list(range(79, 85 + 1))
    crit = (dfm3['Sample'].isin(allowed_samples))
    dfs = dfm3[crit]
    dfs['Sample'] = [str(s).zfill(2) for s in dfs['Sample']]
    return dfs

dfs = get_campaign_c(dfm3)

fig, ax = plt.subplots(figsize = (16, 5))
sns.lineplot(
    x = 'Sample',
    y = 'Frequency',
    hue = 'Full genotype',
    data = dfs,
    ax = ax,
)
sns.despine()
plt.grid(alpha = 0.2)
plt.title(f'LowPANCE1 -> HighPANCE3 -> PACE1');
plt.legend(bbox_to_anchor = (1.05, 1), loc = 'upper left')
# Out:
# /ahg/regevdata/users/maxwshen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
def get_campaign_c(dfm3):
    allowed_samples = list(range(1, 20 + 1)) + list(range(61, 69 + 1)) + list(range(93, 99 + 1))
    crit = (dfm3['Sample'].isin(allowed_samples))
    dfs = dfm3[crit]
    dfs['Sample'] = [str(s).zfill(2) for s in dfs['Sample']]
    return dfs

dfs = get_campaign_c(dfm3)

fig, ax = plt.subplots(figsize = (16, 5))
sns.lineplot(
    x = 'Sample',
    y = 'Frequency',
    hue = 'Full genotype',
    data = dfs,
    ax = ax,
)
sns.despine()
plt.grid(alpha = 0.2)
plt.title(f'LowPANCE1 -> HighPANCE3 -> PACE3');
plt.legend(bbox_to_anchor = (1.05, 1), loc = 'upper left')
# Out:
# /ahg/regevdata/users/maxwshen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
def get_campaign_c(dfm3):
    allowed_samples = list(range(21, 40 + 1)) + list(range(70, 78 + 1)) + list(range(86, 92 + 1))
    crit = (dfm3['Sample'].isin(allowed_samples))
    dfs = dfm3[crit]
    dfs['Sample'] = [str(s).zfill(2) for s in dfs['Sample']]
    return dfs

dfs = get_campaign_c(dfm3)

fig, ax = plt.subplots(figsize = (16, 5))
sns.lineplot(
    x = 'Sample',
    y = 'Frequency',
    hue = 'Full genotype',
    data = dfs,
    ax = ax,
)
sns.despine()
plt.grid(alpha = 0.2)
plt.title(f'LowPANCE2 -> HighPANCE4 -> PACE2');
plt.legend(bbox_to_anchor = (1.05, 1), loc = 'upper left')
# Out:
# /ahg/regevdata/users/maxwshen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
def get_campaign_c(dfm3):
    allowed_samples = list(range(21, 40 + 1)) + list(range(70, 78 + 1)) + list(range(93, 99 + 1))
    crit = (dfm3['Sample'].isin(allowed_samples))
    dfs = dfm3[crit]
    dfs['Sample'] = [str(s).zfill(2) for s in dfs['Sample']]
    return dfs

dfs = get_campaign_c(dfm3)

fig, ax = plt.subplots(figsize = (16, 5))
sns.lineplot(
    x = 'Sample',
    y = 'Frequency',
    hue = 'Full genotype',
    data = dfs,
    ax = ax,
)
sns.despine()
plt.grid(alpha = 0.2)
plt.title(f'LowPANCE2 -> HighPANCE4 -> PACE3');
plt.legend(bbox_to_anchor = (1.05, 1), loc = 'upper left')
# Out:
# /ahg/regevdata/users/maxwshen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %% [markdown]
# ## Plot PACE only

# %%
crit = (dfm3['Sample'] >= 79) & (dfm3['Sample'] <= 85)
dfm_paceonly = dfm3[crit]

fig, ax = plt.subplots()
sns.lineplot(
    x = 'Sample',
    y = 'Frequency',
    hue = 'Full genotype',
    data = dfm_paceonly,
#     style = 'Full genotype',
    ax = ax,
)
sns.despine()
plt.grid(alpha = 0.2)
plt.legend(bbox_to_anchor = (1.05, 1), loc = 'upper left')

# %%
crit = (dfm3['Sample'] >= 86) & (dfm3['Sample'] <= 92)
dfm_paceonly = dfm3[crit]

fig, ax = plt.subplots()
sns.lineplot(
    x = 'Sample',
    y = 'Frequency',
    hue = 'Full genotype',
    data = dfm_paceonly,
#     style = 'Full genotype',
    ax = ax,
)
sns.despine()
plt.grid(alpha = 0.2)
plt.legend(bbox_to_anchor = (1.05, 1), loc = 'upper left')

# %%
crit = (dfm3['Sample'] >= 93) & (dfm3['Sample'] <= 99)
dfm_paceonly = dfm3[crit]

fig, ax = plt.subplots()
sns.lineplot(
    x = 'Sample',
    y = 'Frequency',
    hue = 'Full genotype',
    data = dfm_paceonly,
#     style = 'Full genotype',
    ax = ax,
)
sns.despine()
plt.grid(alpha = 0.2)
plt.legend(bbox_to_anchor = (1.05, 1), loc = 'upper left')

# %% [markdown]
# ## Combine regimes

# %%
dfm3.head()
# Out:
#                                           Full genotype Sample name  \
# 483   ----------------------------------------------...       Fq 41
# 1094  I---------------------------------------------...       Fq 92
# 646   -------------------------C--------------------...       Fq 54
# 510   ----------------------------------------------...       Fq 43
# 1004  ----------------------------------------------...       Fq 84
#
#       Frequency  Sample
# 483    0.131011      41
# 1094   0.000000      92
# 646    0.000000      54
# 510    0.000000      43
# 1004   0.031847      84

# %%
aligned_highpance = {
    '1': [41, 42, 45, 44, 46, 47, 48, 49, 50],
    '2': [51, 52, 55, 54, 56, 57, 58, 59, 60],
    '3': [61, 62, 65, 64, 65, 66, 67, 68, 69],
    '4': [70, 71, 72, 73, 74, 75, 76, 77, 78],
}

def merge_highpances(df):
    num_samples = len(aligned_highpance['1'])
    
    new_df = pd.DataFrame()
    for idx in range(num_samples):
        new_samplenm = f'Fq {41 + idx}'

        samples = [f'Fq {aligned_highpance[highpance][idx]}' for highpance in aligned_highpance]
        dfs = df[df['Sample name'].isin(samples)]
        
        pv_df = dfs.pivot(index = 'Full genotype', columns = 'Sample name', values = 'Frequency')
        pv_df = pv_df.fillna(value = 0)
        pv_df['Mean fq'] = pv_df.apply(np.mean, axis = 'columns')
        pv_df['Mean fq'] /= sum(pv_df['Mean fq'])
        pv_df['Full genotype'] = pv_df.index
        pv_df = pv_df[['Full genotype' , 'Mean fq']]
        
        dfm = pv_df.melt(id_vars = ['Full genotype'], value_name = 'Frequency')
        dfm['Sample name'] = new_samplenm
        dfm['Sample'] = 41 + idx
        
        new_df = new_df.append(dfm, ignore_index = True)
        
    return new_df

ndf = merge_highpances(dfm3)

# %%
aligned_lowpance = {
    '1': list(range(1, 20 + 1)),
    '2': list(range(21, 40 + 1)),
}

def merge_lowpances(df):
    num_samples = len(aligned_lowpance['1'])
    
    new_df = pd.DataFrame()
    for idx in range(num_samples):
        new_samplenm = f'Fq {1 + idx}'

        samples = [f'Fq {aligned_lowpance[pance][idx]}' for pance in aligned_lowpance]
        dfs = df[df['Sample name'].isin(samples)]
        
        pv_df = dfs.pivot(index = 'Full genotype', columns = 'Sample name', values = 'Frequency')
        pv_df = pv_df.fillna(value = 0)
        pv_df['Mean fq'] = pv_df.apply(np.mean, axis = 'columns')
        pv_df['Mean fq'] /= sum(pv_df['Mean fq'])
        pv_df['Full genotype'] = pv_df.index
        pv_df = pv_df[['Full genotype' , 'Mean fq']]
        
        dfm = pv_df.melt(id_vars = ['Full genotype'], value_name = 'Frequency')
        dfm['Sample name'] = new_samplenm
        dfm['Sample'] = 1 + idx
        
        new_df = new_df.append(dfm, ignore_index = True)
        
    return new_df

ndf = merge_lowpances(dfm3)

# %%
aligned_pace = {
    '2': list(range(86, 92 + 1)),
    '3': list(range(93, 99 + 1)),
}

def merge_paces(df):
    num_samples = len(aligned_pace['2'])
    
    new_df = pd.DataFrame()
    for idx in range(num_samples):
        new_samplenm = f'Fq {93 + idx}'

        samples = [f'Fq {aligned_pace[pace][idx]}' for pace in aligned_pace]
        dfs = df[df['Sample name'].isin(samples)]
        
        pv_df = dfs.pivot(index = 'Full genotype', columns = 'Sample name', values = 'Frequency')
        pv_df = pv_df.fillna(value = 0)
        pv_df['Mean fq'] = pv_df.apply(np.mean, axis = 'columns')
        pv_df['Mean fq'] /= sum(pv_df['Mean fq'])
        pv_df['Full genotype'] = pv_df.index
        pv_df = pv_df[['Full genotype' , 'Mean fq']]
        
        dfm = pv_df.melt(id_vars = ['Full genotype'], value_name = 'Frequency')
        dfm['Sample name'] = new_samplenm
        dfm['Sample'] = 93 + idx
        
        new_df = new_df.append(dfm, ignore_index = True)
        
    return new_df

ndf = merge_paces(dfm3)

# %%
#
low_df = merge_lowpances(dfm3)
high_df = merge_highpances(dfm3)
pace_df = dfm3[dfm3['Sample'].isin(list(range(86, 92 + 1)))]

merged_df = low_df.append(high_df, ignore_index = True, sort = False)
merged_df = merged_df.append(pace_df, ignore_index = True, sort = False)
merged_df['Sample'] = [str(s).zfill(2) for s in merged_df['Sample']]

fig, ax = plt.subplots(figsize = (16, 5))
sns.lineplot(
    x = 'Sample',
    y = 'Frequency',
    hue = 'Full genotype',
    data = merged_df,
    ax = ax,
)
sns.despine()
plt.grid(alpha = 0.2)
plt.title(f'Merged low PANCE -> Merged high PANCE -> PACE2');
plt.legend(bbox_to_anchor = (1.05, 1), loc = 'upper left')

# %%
#
low_df = merge_lowpances(dfm3)
high_df = merge_highpances(dfm3)
pace_df = merge_paces(dfm3)

merged_df = low_df.append(high_df, ignore_index = True, sort = False)
merged_df = merged_df.append(pace_df, ignore_index = True, sort = False)
merged_df['Sample'] = [str(s).zfill(2) for s in merged_df['Sample']]

fig, ax = plt.subplots(figsize = (16, 5))
sns.lineplot(
    x = 'Sample',
    y = 'Frequency',
    hue = 'Full genotype',
    data = merged_df,
    ax = ax,
)
sns.despine()
plt.grid(alpha = 0.2)
plt.title(f'Merged low PANCE -> Merged high PANCE -> Merged PACE');
plt.legend(bbox_to_anchor = (1.05, 1), loc = 'upper left')

# %%
#
low_df = dfm3[dfm3['Sample'].isin(list(range(1, 20 + 1)))]
high_df = merge_highpances(dfm3)
pace_df = dfm3[dfm3['Sample'].isin(list(range(86, 92 + 1)))]

merged_df = low_df.append(high_df, ignore_index = True, sort = False)
merged_df = merged_df.append(pace_df, ignore_index = True, sort = False)
merged_df['Sample'] = [str(s).zfill(2) for s in merged_df['Sample']]

fig, ax = plt.subplots(figsize = (16, 5))
sns.lineplot(
    x = 'Sample',
    y = 'Frequency',
    hue = 'Full genotype',
    data = merged_df,
    ax = ax,
)
sns.despine()
plt.grid(alpha = 0.2)
plt.title(f'LowPANCE1 -> Merged high PANCE -> PACE2');
plt.legend(bbox_to_anchor = (1.05, 1), loc = 'upper left')

# %%
#
low_df = dfm3[dfm3['Sample'].isin(list(range(1, 20 + 1)))]
high_df = merge_highpances(dfm3)
pace_df = dfm3[dfm3['Sample'].isin(list(range(93, 99 + 1)))]

merged_df = low_df.append(high_df, ignore_index = True, sort = False)
merged_df = merged_df.append(pace_df, ignore_index = True, sort = False)
merged_df['Sample'] = [str(s).zfill(2) for s in merged_df['Sample']]

fig, ax = plt.subplots(figsize = (16, 5))
sns.lineplot(
    x = 'Sample',
    y = 'Frequency',
    hue = 'Full genotype',
    data = merged_df,
    ax = ax,
)
sns.despine()
plt.grid(alpha = 0.2)
plt.title(f'LowPANCE1 -> Merged high PANCE -> PACE3');
plt.legend(bbox_to_anchor = (1.05, 1), loc = 'upper left')

# %%
#
low_df = dfm3[dfm3['Sample'].isin(list(range(21, 40 + 1)))]
high_df = merge_highpances(dfm3)
pace_df = dfm3[dfm3['Sample'].isin(list(range(93, 99 + 1)))]

merged_df = low_df.append(high_df, ignore_index = True, sort = False)
merged_df = merged_df.append(pace_df, ignore_index = True, sort = False)
merged_df['Sample'] = [str(s).zfill(2) for s in merged_df['Sample']]

fig, ax = plt.subplots(figsize = (16, 5))
sns.lineplot(
    x = 'Sample',
    y = 'Frequency',
    hue = 'Full genotype',
    data = merged_df,
    ax = ax,
)
sns.despine()
plt.grid(alpha = 0.2)
plt.title(f'LowPANCE2 -> Merged high PANCE -> PACE3');
plt.legend(bbox_to_anchor = (1.05, 1), loc = 'upper left')

# %%
#
low_df = dfm3[dfm3['Sample'].isin(list(range(21, 40 + 1)))]
high_df = merge_highpances(dfm3)
pace_df = dfm3[dfm3['Sample'].isin(list(range(79, 85 + 1)))]

merged_df = low_df.append(high_df, ignore_index = True, sort = False)
merged_df = merged_df.append(pace_df, ignore_index = True, sort = False)
merged_df['Sample'] = [str(s).zfill(2) for s in merged_df['Sample']]

fig, ax = plt.subplots(figsize = (16, 5))
sns.lineplot(
    x = 'Sample',
    y = 'Frequency',
    hue = 'Full genotype',
    data = merged_df,
    ax = ax,
)
sns.despine()
plt.grid(alpha = 0.2)
plt.title(f'LowPANCE2 -> Merged high PANCE -> PACE1');
plt.legend(bbox_to_anchor = (1.05, 1), loc = 'upper left')
